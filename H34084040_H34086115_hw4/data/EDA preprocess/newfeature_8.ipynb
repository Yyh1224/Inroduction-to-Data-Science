# %% [markdown]
# ### 1. Load Preprocess Data

# %%
import matplotlib as plt
from matplotlib import *
from hw4_library import *
import matplotlib.style
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %%
direct = 'C:/Users/yuanhsu/Desktop/111-1/資料科學導論/hw4/csv'
train_o = pd.read_csv(direct+"/train.csv")
test_o = pd.read_csv(direct+"/test.csv")

# %% [markdown]
# train_df.shape (8000, 14)
# test_df.shape (2000, 14)

# %% [markdown]
# ### Feature engineering

# %%
train_new = train_o
train_new['TenureByAge'] = train_o.Tenure/(train_o.Age)
test_new = test_o
test_new['TenureByAge'] = test_o.Tenure/(test_o.Age)

# %%
train_new['BalanceSalaryRatio'] = train_new.Balance/train_new.EstimatedSalary
test_new['BalanceSalaryRatio'] = test_new.Balance/test_new.EstimatedSalary

# %%
train_new['CreditScoreGivenAge'] = train_new.CreditScore/(train_new.Age)
test_new['CreditScoreGivenAge'] = test_new.CreditScore/(test_new.Age)

# %% [markdown]
# ### more features

# %%
train_new['BalanceAge'] = train_new.Balance/(train_new.Age)
test_new['BalanceAge'] = test_new.Balance/(test_new.Age)
train_new['EstimatedSalaryAge'] = train_new.EstimatedSalary/(train_new.Age)
test_new['EstimatedSalaryAge'] = test_new.EstimatedSalary/(test_new.Age)
train_new['CreditScoreSalaryRatio'] = train_new.CreditScore/train_new.EstimatedSalary
test_new['CreditScoreSalaryRatio'] = test_new.CreditScore/test_new.EstimatedSalary
###
train_new['TenureSalaryRatio'] = train_new.Tenure/train_new.EstimatedSalary
test_new['TenureSalaryRatio'] = test_new.Tenure/test_new.EstimatedSalary
train_new['NumOfProductsSalaryRatio'] = train_new.NumOfProducts/train_new.EstimatedSalary
test_new['NumOfProductsSalaryRatio'] = test_new.NumOfProducts/test_new.EstimatedSalary

# %%
train_new.head()
# Out:
#    RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0        551    15806307   Trevisano          720     Spain    Male   38
# 1       6897    15709621      Martin          682    France  Female   54
# 2       4588    15619340      Palmer          672    France  Female   31
# 3        291    15620746  Napolitani          592     Spain  Female   40
# 4       1673    15646372         Yao          753     Spain    Male   42
#
#    Tenure    Balance  NumOfProducts  ...  EstimatedSalary  Exited  \
# 0       5  114051.97              2  ...        107577.29       0
# 1       4   62397.41              1  ...        113088.60       1
# 2       5  119903.67              1  ...        132925.17       0
# 3       4  104257.86              1  ...        110857.33       0
# 4       5  120387.73              1  ...        126378.57       0
#
#    TenureByAge  BalanceSalaryRatio  CreditScoreGivenAge   BalanceAge  \
# ...

# %% [markdown]
# ### Data preprocess

# %%
train_pre = preprocess(train_new)
test_pre = preprocess(test_new)
# Out:
# C:\Users\yuanhsu\Desktop\111-1\資料科學導論\hw4\preprocess\hw4_library.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i+'_'+j] = np.where(df[i] == j,1,-1)
# C:\Users\yuanhsu\Desktop\111-1\資料科學導論\hw4\preprocess\hw4_library.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i+'_'+j] = np.where(df[i] == j,1,-1)
# C:\Users\yuanhsu\Desktop\111-1\資料科學導論\hw4\preprocess\hw4_library.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
train_pre.columns
# Out:
# Index(['Exited', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'EstimatedSalary', 'TenureByAge', 'BalanceSalaryRatio',
#        'CreditScoreGivenAge', 'BalanceAge', 'EstimatedSalaryAge',
#        'CreditScoreSalaryRatio', 'TenureSalaryRatio',
#        'NumOfProductsSalaryRatio', 'HasCrCard', 'IsActiveMember',
#        'Geography_Spain', 'Geography_France', 'Geography_Germany',
#        'Gender_Male', 'Gender_Female'],
#       dtype='object')

# %%
test_pre.head()
# Out:
#    CreditScore   Age  Tenure   Balance  NumOfProducts  EstimatedSalary  \
# 0     0.912052  0.22     0.2  0.000000       0.000000         0.572521
# 1     0.700326  0.28     0.2  0.608183       0.000000         0.804225
# 2     0.322476  0.12     0.8  0.000000       0.333333         0.244890
# 3     0.928339  0.28     0.2  0.217697       0.000000         0.925166
# 4     0.283388  0.44     0.8  0.000000       0.000000         0.915482
#
#    TenureByAge  BalanceSalaryRatio  CreditScoreGivenAge  BalanceAge  ...  \
# 0     0.221154            0.067505             0.633888    0.188799  ...
# 1     0.196429            0.269989             0.484251    0.543611  ...
# 2     0.669118            0.161560             0.499402    0.244328  ...
# 3     0.196429            0.089912             0.570928    0.298486  ...
# 4     0.415000            0.010434             0.220159    0.105727  ...
#
#    CreditScoreSalaryRatio  TenureSalaryRatio  NumOfProductsSalaryRatio  \
# ...

# %%
order = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
       'EstimatedSalary', 'TenureByAge', 'BalanceSalaryRatio',
       'CreditScoreGivenAge', 'BalanceAge', 'EstimatedSalaryAge',
       'CreditScoreSalaryRatio', 'TenureSalaryRatio',
       'NumOfProductsSalaryRatio', 'HasCrCard', 'IsActiveMember',
       'Geography_Spain', 'Geography_France', 'Geography_Germany',
       'Gender_Male', 'Gender_Female']
test_pre = test_pre[order]

# %%
train_pre.head()
# Out:
#    Exited  CreditScore       Age  Tenure   Balance  NumOfProducts  \
# 0       0     0.892508  0.188679     0.6  0.409621       0.333333
# 1       1     0.768730  0.490566     0.4  0.000000       0.000000
# 2       0     0.736156  0.056604     0.6  0.456025       0.000000
# 3       0     0.475570  0.226415     0.4  0.331954       0.000000
# 4       0     1.000000  0.264151     0.6  0.459864       0.000000
#
#    EstimatedSalary  TenureByAge  BalanceSalaryRatio  CreditScoreGivenAge  ...  \
# 0         0.589163     0.463158            0.257297             0.595089  ...
# 1         0.654032     0.202469            0.047066             0.267236  ...
# 2         0.887514     0.597849            0.191905             0.736763  ...
# 3         0.627770     0.320000            0.207795             0.379865  ...
# 4         0.810459     0.406349            0.212810             0.542220  ...
#
#    CreditScoreSalaryRatio  TenureSalaryRatio  NumOfProductsSalaryRatio  \
# ...

# %%
# train_pre.to_csv('train_nf_preprocess_1122.csv')
# test_pre.to_csv('test_nf_preprocess_1122.csv')
