# %% [markdown]
# ### Load Preprocess Data

# %%
# !pip install tensorflow
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
import numpy as np
import pandas as pd
# train = pd.read_csv('train_cat_con_preprocess.csv')
# test = pd.read_csv('test_cat_con_preprocess.csv')
train = pd.read_csv('train_nf_preprocess_1122.csv')
test = pd.read_csv('test_nf_preprocess_1122.csv')

# %%
# from modeling_ML import*
# x,y,test=prep_test(train,test)

# %% [markdown]
# train_df.shape (8000, 14)
# test_df.shape (2000, 14)

# %%
# #get ride of feature which correlation <0.03
# train_corr = train.drop(['EstimatedSalary','HasCrCard','Tenure','CreditScore'],axis=1)
#train_corr = train_corr.drop(['Unnamed: 0'],axis=1)
# test_corr = test.drop(['EstimatedSalary','HasCrCard','Tenure','CreditScore'],axis=1)
# test_corr = test_corr.drop(['Unnamed: 0'],axis=1)

# %%
train = train.drop(['Unnamed: 0'],axis=1)
test = test.drop(['Unnamed: 0'],axis=1)
x = train.loc[:, train.columns != 'Exited']
y = train.Exited

# %%
order = x.columns.to_list()
x = x[order]

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.001, random_state = 0,stratify=y)

# %% [markdown]
# #### Feature scaling
# - fundamental step for implementing DL

# %%
# from sklearn.preprocessing import StandardScaler
# #standardize all features mean = 0; std = 1
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %% [markdown]
# ### Building the ANN

# %%
#build seqential neural network
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=21,input_dim = 21, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(1, activation='sigmoid'))
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
ann.fit(x, y, batch_size = 64, epochs = 1000)
# Out:
# Epoch 1/1000
# 125/125 [==============================] - 1s 1ms/step - loss: 0.6035 - accuracy: 0.7937
# Epoch 2/1000
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.7960
# Epoch 3/1000
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.7960
# Epoch 4/1000
# 125/125 [==============================] - 0s 1ms/step - loss: 0.5064 - accuracy: 0.7960
# Epoch 5/1000
# 125/125 [==============================] - 0s 1ms/step - loss: 0.5062 - accuracy: 0.7960
# Epoch 6/1000
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.7960
# Epoch 7/1000
# 125/125 [==============================] - 0s 1ms/step - loss: 0.5064 - accuracy: 0.7960
# Epoch 8/1000
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7960
# Epoch 9/1000
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.7960
# Epoch 10/1000
# ...

# %%
ann.summary()

# %%
# test = sc.transform(test_corr)

# %%
# y_pred = ann.predict(X_test)
# y_pred = (y_pred > 0.5)
y_pred = ann.predict(test)
y_pred = (y_pred > 0.55)

# %%
# print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.values.reshape(len(y_test),1)),1))

# %%
# from sklearn.metrics import confusion_matrix, accuracy_score
# cm = confusion_matrix(y_test, y_pred)
# print(cm)
# accuracy_score(y_test, y_pred)

# %%
len(y_pred)

# %% [markdown]
# ### save prediction result

# %%
df = pd.DataFrame(y_pred)

# %%
direct = 'C:/Users/yuanhsu/Desktop/111-1/資料科學導論/hw4/csv'
# train_o = pd.read_csv(direct+"/train.csv")
# test_o = pd.read_csv(direct+"/test.csv")

# %%
testing = pd.read_csv(direct+"/test.csv")

# %%
res = pd.concat([testing['RowNumber'],df],axis=1)
res.to_csv('NN_21_6_32times_more_nf_0.55.csv')
